# %%
import numpy as np
import pandas as pd

# --------------------------------------
# show several outputs in one cell. 
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# --------------------------------------

# %%
df = pd.read_csv('cost-00001.csv', header=0, sep=',', low_memory=False) 
print(df.shape)
df.head(3)
# Out:
# (5633, 230)
#                                  identity/LineItemId  \
# 0  qwe4bbftl5l52jqmju74p4yrieyhgnnncvl5dslu4zf2st...
# 1  wafvhmbo7dtvuu53rm6v6a4fxxzar3zysjyafskdvextuh...
# 2  g5f2m2hjnssjgg4ktfz75xym4xz4w62yc6gv24asw54wkc...
#
#                        identity/TimeInterval  bill/InvoiceId  \
# 0  2021-11-10T00:00:00Z/2021-11-11T00:00:00Z       918514725
# 1  2021-11-18T00:00:00Z/2021-11-19T00:00:00Z       918514725
# 2  2021-11-18T00:00:00Z/2021-11-19T00:00:00Z       918514725
#
#   bill/BillingEntity bill/BillType  bill/PayerAccountId  \
# 0                AWS   Anniversary         757424326803
# 1                AWS   Anniversary         757424326803
# 2                AWS   Anniversary         757424326803
#
#   bill/BillingPeriodStartDate bill/BillingPeriodEndDate  \
# 0        2021-11-01T00:00:00Z      2021-12-01T00:00:00Z
# 1        2021-11-01T00:00:00Z      2021-12-01T00:00:00Z
# 2        2021-11-01T00:00:00Z      2021-12-01T00:00:00Z
#
# ...

# %%
result = df.copy()

for i in range(300):
    print('Iter:', i)
    df2 = df.copy()
    df2['identity/LineItemId'] = df2['identity/LineItemId'] + str(i)
    result = result.append(df2)

result.to_csv('cost-00003.csv', header=True, index=False, index_label=False)
# Out:
# Iter: 0
# Iter: 1
# Iter: 2
# Iter: 3
# Iter: 4
# Iter: 5
# Iter: 6
# Iter: 7
# Iter: 8
# Iter: 9
# Iter: 10
# Iter: 11
# Iter: 12
# Iter: 13
# Iter: 14
# Iter: 15
# Iter: 16
# Iter: 17
# Iter: 18
# Iter: 19
# Iter: 20
# Iter: 21
# Iter: 22
# Iter: 23
# Iter: 24
# Iter: 25
# Iter: 26
# Iter: 27
# Iter: 28
# Iter: 29
# Iter: 30
# Iter: 31
# Iter: 32
# Iter: 33
# Iter: 34
# Iter: 35
# Iter: 36
# Iter: 37
# Iter: 38
# Iter: 39
# Iter: 40
# Iter: 41
# Iter: 42
# Iter: 43
# Iter: 44
# Iter: 45
# Iter: 46
# Iter: 47
# Iter: 48
# Iter: 49
# Iter: 50
# Iter: 51
# Iter: 52
# Iter: 53
# Iter: 54
# Iter: 55
# Iter: 56
# Iter: 57
# Iter: 58
# Iter: 59
# Iter: 60
# Iter: 61
# Iter: 62
# Iter: 63
# Iter: 64
# Iter: 65
# Iter: 66
# Iter: 67
# Iter: 68
# Iter: 69
# Iter: 70
# Iter: 71
# Iter: 72
# Iter: 73
# Iter: 74
# Iter: 75
# Iter: 76
# Iter: 77
# Iter: 78
# Iter: 79
# Iter: 80
# Iter: 81
# Iter: 82
# Iter: 83
# Iter: 84
# Iter: 85
# Iter: 86
# Iter: 87
# Iter: 88
# Iter: 89
# Iter: 90
# ...
